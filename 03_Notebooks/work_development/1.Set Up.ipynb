# %%
import os
import numpy as np
import pandas as pd
# %config IPCompleter.greedy=True

# %%
path = '../../'

# %% [markdown]
# ## CREATION OF  DATASETS

# %% [markdown]
# ORIGINAL DATA IS IN '/02_Data/01_Original'

# %% [markdown]
# ### Import Data

# %%
name_original_file = 'Leads.csv'

# %%
complete_path = path + '/02_Data/01_Original/' + name_original_file
data = pd.read_csv(complete_path,index_col=0,sep = ';')
data
# Out:
#                          origen          fuente no_enviar_email no_llamar  \
# id
# 660737                      API            Chat              No        No
# 660728                      API  Organic Search              No        No
# 660727  Landing Page Submission  Direct Traffic              No        No
# 660719  Landing Page Submission  Direct Traffic              No        No
# 660681  Landing Page Submission          Google              No        No
# ...                         ...             ...             ...       ...
# 579564  Landing Page Submission  Direct Traffic             Yes        No
# 579546  Landing Page Submission  Direct Traffic              No        No
# 579545  Landing Page Submission  Direct Traffic             Yes        No
# 579538  Landing Page Submission          Google              No        No
# 579533  Landing Page Submission  Direct Traffic              No        No
#
# ...

# %% [markdown]
# ### Validation Dataset

# %%
val= data.sample(frac = 0.3)

# %%
name_validation_file = 'validation.csv'
complete_path = path + '/02_Data/02_Validation/' + name_validation_file
val.to_csv(complete_path)

# %% [markdown]
# ### Dataset de trabajo

# %%
work = data.loc[~data.index.isin(val.index)]

# %%
name_work_file = 'work.csv'
complete_path = path + '/02_Data/03_Work/' + name_work_file
work.to_csv(complete_path)
